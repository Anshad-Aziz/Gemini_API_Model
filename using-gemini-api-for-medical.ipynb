# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import google.generativeai as genai
import os

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("key")

# %%
genai.configure(api_key = secret_value_0)

# %%
from IPython.display import Markdown
model=genai.GenerativeModel('gemini-pro')

# %%
response=model.generate_content("You are a doctor! Give me Just a single health tip!")
Markdown(response.text)
# Out:
# **Eat a variety of colorful fruits and vegetables.**
#
# * Aim for at least five servings per day.
# * Choose fruits and vegetables of all colors, as each color provides different nutrients.
# * Fruits and vegetables are low in calories and fat, and they're packed with vitamins, minerals, and fiber.
# * Eating a variety of fruits and vegetables can help you maintain a healthy weight, reduce your risk of chronic diseases like heart disease and cancer, and improve your overall health and well-being.

# %%
age="20"
gender="male"
occupation="student"
nationality="Indian"
weight="70"
health_insurance="yes"

existing_medical_symptoms="cough& cold,runny nose,frequent fever"
chronic_diseases="none"
allergies="none"
previous_surgeries="none"
current_medications="antibiotic medicine for cough & cold"

smoking_status="none"
alcohol_intake="none"
occasional_drug_use="none"

# %%
# creating a prompt template for our patient
prompt = "Patient is a {0} year old {1}".format(age, gender)
prompt += "Patient is {0} and is works as a {1}.".format(nationality, occupation)
prompt += "Patient weighs {0} and their health insurance status is {1}".format(weight,health_insurance)
prompt += "Patient also has some existing medical symptoms like {0}.".format(existing_medical_symptoms)
prompt += "Patient's chronic disease status is {0}, allergy status is {1}.".format(chronic_diseases, allergies)
prompt += "Patient's previous surgeries are {0} and current medications are {1}.".format(previous_surgeries, current_medications)
prompt += "Patient's smoking status is {0}, alcohol intake is {1} and occasional drug use is {2}.".format(smoking_status, alcohol_intake, occasional_drug_use)
prompt += "You are a renowned doctor. You know everything about diseases and their cures. You will help the patient by recommending him/her medicines and steps he/she should take to get cured at the earliest using the symptoms provided above."

# %%
response=model.generate_content(prompt)
Markdown(response.text)
# Out:
# **Diagnosis:**
#
# Based on the symptoms described, it is likely that the patient has a viral respiratory tract infection, commonly known as the flu. The flu is a contagious respiratory illness caused by influenza viruses that affect the nose, throat, and sometimes the lungs. It is characterized by symptoms such as cough, cold, runny nose, and fever.
#
# **Recommendations:**
#
# 1. **Over-the-Counter Medications:**
#
#    - **Antihistamines:** Over-the-counter antihistamines, such as loratadine (Claritin) or cetirizine (Zyrtec), can help relieve runny nose and sneezing.
#    - **Decongestants:** Decongestants, such as pseudoephedrine (Sudafed) or phenylephrine (Neo-Synephrine), can help relieve nasal congestion.
#    - **Pain relievers and fever reducers:** Acetaminophen (Tylenol) or ibuprofen (Advil) can help relieve fever, aches, and pain.
#
# 2. **Home Remedies:**
#
#    - **Adequate Rest:** Get plenty of rest to allow the body to heal.
# ...
